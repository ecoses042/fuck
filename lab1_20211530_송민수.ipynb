# %% [markdown]
# <a href="https://colab.research.google.com/github/ecoses042/fuck/blob/main/lab1_20211530_%EC%86%A1%EB%AF%BC%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile hello2.c
# #include <stdio.h>
# int main(void)
# {
#     printf("Hello World");
#  return 0;
# }
# Out:
# Overwriting hello2.c

# %%
ls
# Out:
# hello2.c  sample_data/

# %%
# %%shell
# gcc hello2.c -o output
# ./output
# Out:
# Hello World
